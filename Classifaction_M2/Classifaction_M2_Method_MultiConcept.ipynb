# %% [markdown]
# # 概念分群[二]_ 方法 _實際使用
# LastModified : 20160117_2155

# %% [markdown]
# ＠選定要使用的W2V Model (只能擇一，頗占記憶體)

# %%
import gensim
#1__WIKI
#model = gensim.models.Word2Vec.load("W2V_Wiki_Trastd/wiki.zh.sim.seg.trastd.model")

#2__搜狐新闻数据
#model = gensim.models.Word2Vec.load('W2V_SogouCS/SogouCS_Combine.model')

#3__全网新闻数据
model = gensim.models.Word2Vec.load('W2V_SogouCA/SogouCA_Combine.model')

# %% [markdown]
# # 將詞語分類
#
# 使用方法：
#
#     W2V_ClassificationMethod2(Concept,Corpus,SimLevel,SimPercent,PrintResultDic)
#
#     Concept   :[字典]。概念字典。
#                格式為：Key  : 概念的名稱(僅命名,無實質意義)
#                Value: [陣列],內容是可以代表該概念的詞語
#
#     Corpus    :[字串]。[檔名]。存取關鍵字的TXT檔。一行一個。
#                 注意！檔案內第一行要空著！編碼要是UTF-8
#
#     SimLevel  :[浮點數]。[0~1]。相似度門檻。
#
#     SimPercent:[浮點數]。[0~1]。相似成數(百分比)門檻。
#                 必須與概念內詞語相似達到一定程度才能算與此概念相似。
#
#     PrintResultDic:[字串]。['T'or'F']。決定是否要印出分類完的概念字典
#                    (並且顯示與該概念的相似度)

# %%
def W2V_ClassificationMethod2(Concept,Corpus,SimLevel,SimPercent,PrintResultDic):
    #SimLevel = 0.25#　　相似程度
    #SimPercent = 0.2#　　相似比率

    import operator
    cnt = []#　　計算餵進來的總詞量
    Expt = []#　　存W2V無法辨識的詞語
    Remain = []#　　存沒有通過門檻的詞語
    ClassingResult = {}

    for z in Concept:#　　把概念標頭寫進字典
        ClassingResult[z] = {}#　　每個字典的內容都是一個字典

    for q in open(Corpus,'r'):#　　把萃取關鍵字的結果讀出來        
        q = q.strip().decode('utf-8')#　　去空白,解碼
        cnt.append(q)#　　把讀取內容寫進一陣列(計算樣本的資料量用)
        try:
            TmpDic = {}#　　暫時性的字典(比對詞語與各概念的相似度)
            SameConcept = ''#　　用來存放概念,當q直接是某概念時使用
            TmpWord = 'None'#　　用來比對詞語是不是與概念完全吻合,若是,None會被修改掉;反之則維持None(初值)

            #print '@ ->「',q,'」的概念分類開始: '

            for a in Concept:#　　讀取各概念標頭
                TmpList = []#　　暫時性的陣列(存放'詞語'vs'概念內各詞語'的相似度)     
                for b in Concept[a]:#　　讀取個概念內的詞語

                    #####完全ㄧ樣#####
                    if q.encode('utf-8') == b:#　　如果等於
                        #print '---目標詞「',q,'」就在【',a,'】的概念裡'
                        TmpWord = b#　　把詞語指定給TmpWord
                        break#　　跳出迴圈(已經知道跟某詞語完全一樣,就不用再比其他的詞語了)
                    #####

                    if model.similarity(q,b.decode('utf-8')) > SimLevel:#　　如果相似度達門檻
                        TmpList.append(model.similarity(q,b.decode('utf-8')))#　　就把相似度寫進TmpList裡面

                #####完全一樣#####        
                if TmpWord != 'None':#　　不是None(初值)->被修改過->要完全相等才會出現此情況
                    SameConcept = a#　　把現在比對到的概念( EX:輕鬆 )記起來
                    break#　　跳出迴圈(已經知道是屬於哪個概念,就不用再比對其他概念了)
                #####

                #####印出q與一概念比較的詳細數據
                #print '  -目標詞「',q,'」與【',a,'】的相似陣列( 顯示內容為已高於相似度門檻 :',SimLevel,')'
                #print TmpList
                #print '  -其占【',a,'】概念內容的\n   比重為 :',len(TmpList),'/',len(Dic[a])
                #print '   比率為 :',
                #print float(len(TmpList))/float(len(Concept[a]))
                #print '*'
                #####

                if float(len(TmpList))/float(len(Concept[a])) > SimPercent:#　　如果達到相似成數的門檻
                    #print '  -「',q,'」已過相似_百分比_門檻 :',SimPercent
                    TmpAvg = 0.0#　　存放平均相似度
                    for c in TmpList:#　　把每個相似度讀出來
                        TmpAvg += c#　　加起來
                    TmpDic[a] = float(TmpAvg)/float(len(TmpList))#　　把'總數'除以'陣列長度',得到平均相似度,
                                                                    #再寫進字典裡,當q與多個概念都有相似度食
                                                                    #可以比較與哪個概念的相似度比較高
                    #print '   與【',a,'】的相似度為: ',TmpDic[a],' -> 進入候選名單'
                    #print '# # # # # # #\n'

            #####完全一樣##### 
            if TmpWord != 'None': 
                ClassingResult[SameConcept][(q.encode('utf-8'))] = 1#　　把q寫進總字典的概念裡(Key:q Value:1)
                continue
            #####

            #####檢視暫存字典#####
            #print '\n___檢視',q,'的暫存字典(TmpDic)___'
            #for k in TmpDic:#　　遍歷暫存字典,看q與個概念的相似度
            #    print k,TmpDic[k]
            #print '== == == == == == == == == == =='
            #####

            if len(TmpDic) > 0:#　　如果暫存字典有任何一概念(表示q'至少'與一個概念相似)
                #print '> >小結 :',q,'成功歸類！',
                for d in TmpDic:#　　遍歷TmpDic
                    if d == sorted(TmpDic.iteritems(),key=operator.itemgetter(1),reverse=True)[0][0]:
                        #如果d = 排序後的第一名 (表示d就是與q最像的概念)
                        if TmpDic[d] > SimLevel:#　　如果"q與概念的相似度"大於相似度門檻
                            #print '類別為 :',d,'\n'
                            ClassingResult[d][q.encode('utf-8')] = TmpDic[d]#　　把q寫進總字典的概念裡(Key:q Value:相似度)
                        else:#　　不太可能發生的情況
                            Remain.append('WHAT!?'+q.encode('utf-8'))                    
            else:#　　q與各概念相似度都沒有達標,無法歸類
                Remain.append(q.encode('utf-8'))

        except KeyError:#　　抓到KeyError( W2V不認識q )的例外處理
            #print '「',q,'」EXCEPT! (KeyError)\n'
            Expt.append(q.encode('utf-8'))#　　把q加進例外的陣列理

    ###########檢視總字典#####
    ComfirmDic=['True','T','t','Yes','Y','y']
    if PrintResultDic in ComfirmDic:
        print '\n+ + + 印出字典看看 + + +'
        for ee in ClassingResult:
            print ee,str(ClassingResult[ee]).decode('string_escape')
        print '+ + + + + + + + + + + +'
    ###########

    print '原總量',len(cnt),'\t|','去重複後',len(set(cnt))
    print '--------------------------------------------------'        

    Scnt = 0#　　計算成功被歸類的數量
    for e in ClassingResult:#　　遍歷各概念
        print '【',e,'】','\t數量:',len(ClassingResult[e])
        for f in ClassingResult[e]:#　　遍歷被歸類到此概念中的詞語　
            print f,#　　若加ClassingResult[e][f]則會印出詞語與概念的相似度
            Scnt += 1
        print '\n'

    print '--------------------------------------------------------------------'
    print '相似度門檻',SimLevel,'\t|','相似成數門檻',SimPercent,'　|',\
          '成功分類',Scnt,'　|','成功分類比率',int(float(Scnt)/float(len(set(cnt)))*100),'%'
    print '--------------------------------------------------------------------\n'

    #在此之前Expt 和 Remain都是List , 都有照順序排好 , 印出來可檢查這些詞的原順序
    #此時把List轉成Set , 去除重複值 , 增加可讀性
    Expt = set(Expt)
    Remain = set(Remain)

    #把W2V不認識的印出來
    print '【W2V無法辨識】\t數量',len(Expt)
    for g in Expt:
        print g,
    print '\n'

    #把沒過門檻值的印出來
    print '【低於門檻值】\t數量',len(Remain)
    for h in Remain:
        print h,
    print '\n'

# %% [markdown]
# # 概念字典

# %%
Dic = {
'藝文':['藝術','美術','戲劇','音樂'],\
    
'信仰':['信仰','祭祀','祭拜','膜拜','信眾','信奉'],\
    
'美食':['美食','爽口','美味','好吃'],\
'新奇':['新奇','新穎','獵奇','獨特','驚喜'],\

'輕鬆':['輕鬆','休閒','遊憩','悠閒','休憩','消遣','愜意','放鬆'],\
'遊玩':['遊玩','好玩','遊樂'],\
'快樂':['快樂','愉快','開心','歡樂','幸福','美好'],\
'有趣':['有趣','趣味'],\

'脫俗':['脫俗','幽雅','清幽','優雅','氣質','心曠神怡'],\
'樂活':['環保','綠化','清新'],\

'安靜':['安靜','寧靜'],\
'乾淨':['乾淨','整潔','潔淨'],\

'懷舊':['懷舊','復古','情調'],\
'古老':['古老','悠久'],\

'髒亂':['骯髒','很髒','髒亂','低劣','灰塵','破舊'],\

'購物':['商圈','百貨','商場'],\
'特產':['特產','紀念品'],\

'運動':['運動','健康'],\

'漂亮':['漂亮','可愛','美麗','優美'],\
'文青':['清新','優雅','氣質'],\

'壯觀':['雄偉','壯觀','壯麗']
}

# %%
W2V_ClassificationMethod2(Dic,'NE_SciTfidf-10-20160117.txt',0.25,0.6,'T')
# Out:
# + + + 印出字典看看 + + +
# 遊玩 {'度假': 0.3096833531214933, '遊樂園': 0.32768053245268053, '好玩': 1, '遊樂': 1, '露營': 0.29528809776644405, '遊玩': 1, '碰碰車': 0.3619909262408746, '小棧': 0.28054490940486254}
# 新奇 {'新穎': 1, '絕佳': 0.32800241524353346, '獨特': 1, '寓教於樂': 0.3450672723377153, '驚喜': 1}
# 懷舊 {'舊時代': 0.284288152784181, '復古': 1, '音樂會': 0.2620802045676628, '搖滾音樂': 0.2824867789631999, '感傷': 0.3637476105403455, '小品': 0.3290444689010642, '慢活': 0.3506380591235201, '時裝': 0.30392221099051764, '美聲': 0.3023288859771273}
# 乾淨 {'寬敞': 0.3541934325459053, '整潔': 1, '整齊': 0.3715691872839154, '乾淨': 1, '偏貴': 0.2618165220958864, '低廉': 0.2919366587645278, '溫泉水': 0.3350353776815931, '熱水': 0.35110431905430467, '自然光': 0.34683370320016316, '靜肅': 0.27476020361348097, '親民': 0.3122606265694664, '潔淨': 1, '舒服': 0.36818094265146406}
# 藝文 {'交響樂': 0.2793796688250831, '戲劇': 1, '藝術': 1, '音樂': 1, '戲曲': 0.440171915721983, '攝影': 0.49005040727639315, '音樂廳': 0.3160506988639727, '創意': 0.3755334073713627, '美術': 1}
# 信仰 {'虔誠': 0.4300783023603412, '祈禱': 0.3860988160713566, '信仰': 1, '宗教': 0.43301257858550873, '城隍廟': 0.33561155656035946, '寺廟': 0.36246771684398915, '財神': 0.3422294828659639, '誠心': 0.2968257214410864, '拜拜': 0.3349205197103302, '廟宇': 0.503330418035897, '金紙': 0.38411916038092664, '靈驗': 0.46628872493594686, '神祇': 0.5234203854286584, '祈福': 0.455540005991277, '銅像': 0.3105968616372483, '還願': 0.4434446636211706, '善男信女': 0.36398077377251814, '城隍': 0.47197734037115086, '大廟': 0.3350979206368257, '神殿': 0.3662309453486576, '祭祀': 1, '神明': 0.5645932082687286, '參拜': 0.48706491755018294, '習俗': 0.496896901531844, '道教': 0.5213823229440174, '城隍爺': 0.447863237948879, '佛教': 0.4060304391780948, '佛像': 0.36493370659037, '信徒': 0.5189362468493787}
# 運動 {'運動': 1, '教育': 0.35404874572800993}
# 漂亮 {'漂亮': 1, '深愛': 0.3171843958785267, '勇敢': 0.4195332877757379, '真棒': 0.34753657066030225, '平凡': 0.42327927951540123, '喜歡': 0.44592067095707694, '優美': 1, '很漂亮': 0.424263303905257, '好看': 0.4007300924489709, '棒極了': 0.34836324238341687, '可愛': 1, '美麗': 1, '最棒': 0.30697214453473437, '小風': 0.35175409504258964, '奇怪': 0.38778826318456233, '好棒': 0.30519312712849134, '年輕': 0.3834185154430072}
# 脫俗 {'親切': 0.47238809849681535, '清靜': 0.3300203258170601, '優雅': 1, '清幽': 1, '繁華都市': 0.3275174832974884, '幽雅': 1}
# 髒亂 {'飢腸轆轆': 0.3721073385534104, '合適': 0.30059179922688284, '便宜': 0.3067723300354541, '舒適感': 0.35161755423909336, '物超所值': 0.3856035176515779, '乘涼': 0.3277338952728448, '敏感': 0.3246428565041485, '很髒': 1, '髒亂': 1, '低劣': 1, '誤導': 0.2737453139997674, '浪費': 0.3351276193946401, '灰塵': 1, '嘴饞': 0.42329689644612634, '不好玩': 0.35620979481996773, '乾枯': 0.3351630622139943, '擁擠': 0.35561741804478725, '玩水': 0.36680385740367594, '敗筆': 0.302820402790676, '難以想象': 0.3630273146753878}
# 樂活 {'環保': 1, '自然環境': 0.3274754865583058, '建築設計': 0.3498037502518016, '綠化': 1, '設計規劃': 0.36654543842799764, '生活空間': 0.3298613131143021, '動植物': 0.26485122666105154, '園藝': 0.3013726265790607}
# 壯觀 {'陡峭': 0.37538252240347586, '池水': 0.270210447912673, '古色古香': 0.44311038225879223, '綠樹': 0.3172985678966022, '湖面': 0.3058945664576363, '古色': 0.3099579106697232, '必去': 0.2791786135895675, '園林': 0.2771635616256774, '長廊': 0.28130265999078713, '奇觀': 0.303385188591444, '雅緻': 0.2961419021304923, '點綴著': 0.32982507968809954, '壁畫': 0.33860427700735274, '建築風格': 0.3964818055980464, '雕像': 0.27163801673298826, '熱帶植物': 0.2840201446330187, '莊嚴': 0.31251469816028865, '雕刻': 0.3252864164138158, '空氣清新': 0.345352554619407, '精美': 0.39929011841123857, '宮殿式': 0.340269731721454, '雕塑': 0.3020348541093318, '熱鬧': 0.3784972403847817, '拱橋': 0.26831738837020924, '年久失修': 0.26135747236996093}
# 古老 {'古舊': 0.3651831025096378, '古老': 1, '繁華': 0.33626230008099944, '糟糕': 0.3035618078174023, '古代': 0.37855723340360525, '歷史悠久': 0.5213709630161938, '著名': 0.34946513607669794}
# 美食 {'泡湯': 0.30424228649263557, '品茶': 0.37688695187254123, '豬血': 0.41653664156835135, '好吃': 1, '花生糖': 0.3825108497887958, '叫賣': 0.36854531511332017, '爽口': 1, '鵝肉': 0.38942758484582607, '魯肉': 0.38065447835164523, '新鮮': 0.4411238458065579, '黃記': 0.28139494699858264, '沁涼': 0.36093688785497885, '美食': 1, '老字號': 0.31203478411566304, '臭豆腐': 0.4487107833094546, '吳寶春': 0.36012388222282093, '舒壓': 0.37784192945395634, '美味': 1, '意麵': 0.42998718486759074, '潤餅': 0.3730460510121295, '刈包': 0.37540224340877815, '應有盡有': 0.34874153456276197}
# 安靜 {'寧靜': 1, '安靜': 1, '溫暖': 0.456516893858958}
# 特產 {'紀念品': 1, '手工藝品': 0.42099647404598556, '小食': 0.3474623368507006, '茶具': 0.3086484357477612, '一應俱全': 0.34354571383409427, '釀酒廠': 0.28703353871370885, '日常用品': 0.42440171443117447, '花卉': 0.3251013632529698, '工藝品': 0.40975138022451496}
# 購物 {'摩天大樓': 0.2822576782120434, '晴光': 0.44930779913053903, '購物中心': 0.48383050489882784, '夜景': 0.29573020099863423, '地下街': 0.40173920209767183, '展場': 0.3034782431043648, '梅龍鎮': 0.2649493302610765, '攤商': 0.35336694040389677, '購物': 0.4232249041221167, '電影院': 0.3319155054066837, '零售店': 0.4481372544781064, '花博': 0.3421070441489862, '夜市': 0.4044192248551388, '地下商場': 0.45429725687187483, '鞋店': 0.37502505561681676, '碧湖': 0.29969591711642285, '精品店': 0.43037005130773853, '便利店': 0.4160315136158139, '小而美': 0.2581589419508714, '晶華': 0.3692525622796516, '花市': 0.3628646110186581, '菸廠': 0.3572952977657077, '主題公園': 0.26963850774349474, '兒童樂園': 0.32937541172023466, '中央公園': 0.37952469413377476, '花旗銀行': 0.3495872122991911}
# 有趣 {'豐富': 0.3682724058325888, '很棒': 0.4188756533646098, '感受': 0.32582279802005853, '童話故事': 0.3272537951033153, '值得一看': 0.3870073240452122, '日常生活': 0.2945426072117502, '真實': 0.31918959507693595, '有趣': 1}
# 文青 {'威嚴': 0.4533337136208117, '截然不同': 0.32724852846018926, '熱情奔放': 0.5326976974050001, '愉悅': 0.40339405002179163, '色彩鮮豔': 0.353026585146411, '充滿活力': 0.46752590312445214, '有禮': 0.5002556855404637, '興奮': 0.25397295627587224, '搶眼': 0.3301905069625482, '精緻': 0.4496971527754012, '現代感': 0.44992969765710517, '莊重': 0.442137885376282, '柔和': 0.5569418560990532, '異國情調': 0.44575933006358187, '細緻': 0.4627399697632614, '不為人知': 0.393730400701521, '驚訝': 0.25832386027631804}
# 快樂 {'遺憾': 0.3144652933933929, '值得': 0.3056974458738692, '吃不消': 0.3175672534312083, '遙遠': 0.33934443276088044, '愉快': 1, '幸福': 1, '情不自禁': 0.32464301221170405, '希望': 0.2888781354558625, '歡樂': 1}
# 輕鬆 {'戲水': 0.3173969143012135, '美景': 0.30477135210828366, '悠閒': 1, '放鬆': 1, '休閒': 1, '聊天': 0.2801568139289377, '消遣': 1, '泡溫泉': 0.3733818332576805, '愜意': 1, '輕鬆': 1}
# + + + + + + + + + + + +
# 原總量 955 	| 去重複後 571
# --------------------------------------------------
# 【 遊玩 】 	數量: 8
# 度假 遊樂園 好玩 遊樂 露營 遊玩 碰碰車 小棧
#
# 【 新奇 】 	數量: 5
# 新穎 絕佳 獨特 寓教於樂 驚喜
#
# 【 懷舊 】 	數量: 9
# 舊時代 復古 音樂會 搖滾音樂 感傷 小品 慢活 時裝 美聲
#
# 【 乾淨 】 	數量: 13
# 寬敞 整潔 整齊 乾淨 偏貴 低廉 溫泉水 熱水 自然光 靜肅 親民 潔淨 舒服
#
# 【 藝文 】 	數量: 9
# 交響樂 戲劇 藝術 音樂 戲曲 攝影 音樂廳 創意 美術
#
# 【 信仰 】 	數量: 29
# 虔誠 祈禱 信仰 宗教 城隍廟 寺廟 財神 誠心 拜拜 廟宇 金紙 靈驗 神祇 祈福 銅像 還願 善男信女 城隍 大廟 神殿 祭祀 神明 參拜 習俗 道教 城隍爺 佛教 佛像 信徒
#
# 【 運動 】 	數量: 2
# 運動 教育
#
# 【 漂亮 】 	數量: 17
# 漂亮 深愛 勇敢 真棒 平凡 喜歡 優美 很漂亮 好看 棒極了 可愛 美麗 最棒 小風 奇怪 好棒 年輕
#
# 【 脫俗 】 	數量: 6
# 親切 清靜 優雅 清幽 繁華都市 幽雅
#
# 【 髒亂 】 	數量: 20
# 飢腸轆轆 合適 便宜 舒適感 物超所值 乘涼 敏感 很髒 髒亂 低劣 誤導 浪費 灰塵 嘴饞 不好玩 乾枯 擁擠 玩水 敗筆 難以想象
#
# 【 樂活 】 	數量: 8
# 環保 自然環境 建築設計 綠化 設計規劃 生活空間 動植物 園藝
#
# 【 壯觀 】 	數量: 25
# 陡峭 池水 古色古香 綠樹 湖面 古色 必去 園林 長廊 奇觀 雅緻 點綴著 壁畫 建築風格 雕像 熱帶植物 莊嚴 雕刻 空氣清新 精美 宮殿式 雕塑 熱鬧 拱橋 年久失修
#
# 【 古老 】 	數量: 7
# 古舊 古老 繁華 糟糕 古代 歷史悠久 著名
#
# 【 美食 】 	數量: 22
# 泡湯 品茶 豬血 好吃 花生糖 叫賣 爽口 鵝肉 魯肉 新鮮 黃記 沁涼 美食 老字號 臭豆腐 吳寶春 舒壓 美味 意麵 潤餅 刈包 應有盡有
#
# 【 安靜 】 	數量: 3
# 寧靜 安靜 溫暖
#
# 【 特產 】 	數量: 9
# 紀念品 手工藝品 小食 茶具 一應俱全 釀酒廠 日常用品 花卉 工藝品
#
# 【 購物 】 	數量: 26
# 摩天大樓 晴光 購物中心 夜景 地下街 展場 梅龍鎮 攤商 購物 電影院 零售店 花博 夜市 地下商場 鞋店 碧湖 精品店 便利店 小而美 晶華 花市 菸廠 主題公園 兒童樂園 中央公園 花旗銀行
#
# 【 有趣 】 	數量: 8
# 豐富 很棒 感受 童話故事 值得一看 日常生活 真實 有趣
#
# 【 文青 】 	數量: 17
# 威嚴 截然不同 熱情奔放 愉悅 色彩鮮豔 充滿活力 有禮 興奮 搶眼 精緻 現代感 莊重 柔和 異國情調 細緻 不為人知 驚訝
#
# 【 快樂 】 	數量: 9
# 遺憾 值得 吃不消 遙遠 愉快 幸福 情不自禁 希望 歡樂
#
# 【 輕鬆 】 	數量: 10
# 戲水 美景 悠閒 放鬆 休閒 聊天 消遣 泡溫泉 愜意 輕鬆
#
# --------------------------------------------------------------------
# 相似度門檻 0.25 	| 相似成數門檻 0.6 　| 成功分類 262 　| 成功分類比率 45 %
# --------------------------------------------------------------------
#
# 【W2V無法辨識】	數量 70
# 真理大學 很便宜 燙腳 喧擾 聳大 非常興奮 沒有必要 也很不錯 新藝術 蚵仔煎 值得關注 粘著劑 有特色 文化活動 有創意 草間彌生 香火鼎盛 不講究 搭貓纜 國家公園 值回票價 不喜歡 指南宮 國家劇院 走往 老攤 白鷺鷥 道地 椰林大道 有教育意義 印象深刻 不舒服 傅鐘 會教 碗粿 很開心 觀光果園 待加強 沒得說 艋舺 織紡品 保生大帝 自動販賣機 看電影 挺好玩 有幫助 藝文活動 地藏菩薩 完好如新 劃在 觀光夜市 米苔目 霧太大 翠玉白菜 孔子廟 歌劇魅影 路跑 容易親近 湯區 圓湯 很遺憾 很幸運 儲存模組 民間信仰 令人愉快 現代藝術 可拍照 很假 高水準 庭址
#
# 【低於門檻值】	數量 239
# 毛骨悚然 淡水河 大熊貓 古厝 犯罪 鬧區 地下城 維護 外雙溪 渭水 可選 臥室 交通阻塞 拓撲 科技 天燈 童年 乘船 拍攝 葡萄 應急 菁桐 熊貓館 古亭 徒步旅行 學府 爬山 臺澎金馬 淡江 小桌子 清境 同性戀 樟樹 菸草 交接儀式 寧夏 紀念館 紀州 北門 國民黨中央 失望 菊展 觀景臺 船舶 夏初 孫中山 健行 讚賞 感興趣 文學 神聖 詬病 擎天 社子島 交通狀況 遊樂場 皇宮 忠烈祠 日系 演唱會 平劇 和平 故宮 探險 河景 硬傷 禮賓 旅行團 草坪 熊貓 彩霞 遺址 紀念堂 國寶級 衛兵 少數民族 綠洲 晚宴 渡輪 動物園 下起 箇舊 轉到 文化公園 館藏 刺激 蔣夫人 碧山 格里芬 評論 漁人 發展史 歷史文物 草地 秋日 棒球 順眼 鬧市 進餐 當代藝術 旅遊團 錄影 太多 紅毛城 古蹟 小鎮 紅玉 嬰幼兒 炎熱 南海路 中山堂 萬華 悠遊 風景 古街 義大利式 浴場 快感 網路服務 銅版 臺大 槍戰 二二八 站崗 彩色 休息 白石 玫瑰園 舒暢 袖珍 靜態 微縮 觀劇 研究所 廟口 大龍峒 碧潭 京劇 南方 志趣 蓮花池 航運 花季 科學 書店 享受 貓纜 矛盾 宋美齡 蔣介石 博物院 火山作用 大腸 藝廊 國父 藥材 夏季 中央研究院 負面 特別 硫磺 茶館 微型 建國中學 好訊息 拍照 錦上添花 食品街 瑞芳 酒廠 陳列館 植物園 天鵝 聖誕樹 水上公園 安然 四合院 陵墓 高品質 大使館 教育館 喚起 校門 開放日 職棒 沐浴露 遊樂區 平溪 自然 運輸工具 詔書 湯屋 劍南 展演 友好 說得過去 陰曆 免費參觀 噪聲 海芋 歷史記錄 展示館 國家博物館 山嶺 高階 仙公廟 蔣公 航海 度假村 繁忙 蛤殼 或位 和諧 藝術品 徒步 氣焰囂張 美術館 紅樓 大海 悲慘 試一下 老街 爆竹 登山 天下第一 中國武術 首善之區 慶祝 航海技術 蔣中正 舞會 藝文 圓通寺 著門 火山口 出土文物 陽明 自行車道 偏遠

# %%
W2V_ClassificationMethod2(Dic,'NE_SciTfidf-10-20160117.txt',0.3,0.67,'F')
# Out:
# 原總量 955 	| 去重複後 571
# --------------------------------------------------
# 【 遊玩 】 	數量: 3
# 遊玩 好玩 遊樂
#
# 【 新奇 】 	數量: 3
# 新穎 獨特 驚喜
#
# 【 懷舊 】 	數量: 1
# 復古
#
# 【 乾淨 】 	數量: 3
# 整潔 潔淨 乾淨
#
# 【 藝文 】 	數量: 7
# 戲劇 藝術 音樂 戲曲 攝影 創意 美術
#
# 【 信仰 】 	數量: 17
# 虔誠 城隍 靈驗 神祇 祈福 信仰 習俗 道教 參拜 城隍爺 還願 祈禱 寺廟 祭祀 信徒 神明 廟宇
#
# 【 運動 】 	數量: 1
# 運動
#
# 【 漂亮 】 	數量: 11
# 漂亮 勇敢 平凡 喜歡 優美 感傷 深愛 可愛 美麗 年輕 奇怪
#
# 【 脫俗 】 	數量: 3
# 優雅 清幽 幽雅
#
# 【 髒亂 】 	數量: 5
# 髒亂 低劣 很髒 灰塵 難以想象
#
# 【 樂活 】 	數量: 2
# 環保 綠化
#
# 【 壯觀 】 	數量: 6
# 陡峭 建築風格 古色古香 精美 空氣清新 壁畫
#
# 【 古老 】 	數量: 6
# 古舊 古老 繁華 古代 歷史悠久 著名
#
# 【 美食 】 	數量: 18
# 鵝肉 臭豆腐 魯肉 新鮮 舒壓 刈包 美味 吳寶春 意麵 美食 潤餅 花生糖 好吃 豬血 應有盡有 品茶 叫賣 爽口
#
# 【 安靜 】 	數量: 3
# 寧靜 安靜 溫暖
#
# 【 特產 】 	數量: 5
# 一應俱全 紀念品 手工藝品 日常用品 工藝品
#
# 【 購物 】 	數量: 6
# 攤商 購物 兒童樂園 地下商場 購物中心 地下街
#
# 【 有趣 】 	數量: 5
# 有趣 豐富 熱鬧 童話故事 不為人知
#
# 【 文青 】 	數量: 12
# 熱情奔放 愉悅 色彩鮮豔 充滿活力 有禮 現代感 精緻 莊重 柔和 異國情調 細緻 親切
#
# 【 快樂 】 	數量: 3
# 愉快 幸福 歡樂
#
# 【 輕鬆 】 	數量: 6
# 放鬆 悠閒 休閒 消遣 愜意 輕鬆
#
# --------------------------------------------------------------------
# 相似度門檻 0.3 	| 相似成數門檻 0.67 　| 成功分類 126 　| 成功分類比率 22 %
# --------------------------------------------------------------------
#
# 【W2V無法辨識】	數量 70
# 真理大學 很便宜 燙腳 喧擾 聳大 非常興奮 沒有必要 也很不錯 新藝術 蚵仔煎 值得關注 粘著劑 有特色 文化活動 有創意 草間彌生 香火鼎盛 不講究 搭貓纜 國家公園 值回票價 不喜歡 指南宮 國家劇院 走往 老攤 白鷺鷥 道地 椰林大道 有教育意義 印象深刻 不舒服 傅鐘 會教 碗粿 很開心 觀光果園 待加強 沒得說 艋舺 織紡品 保生大帝 自動販賣機 看電影 挺好玩 有幫助 藝文活動 地藏菩薩 完好如新 劃在 觀光夜市 米苔目 霧太大 翠玉白菜 孔子廟 歌劇魅影 路跑 容易親近 湯區 圓湯 很遺憾 很幸運 儲存模組 民間信仰 令人愉快 現代藝術 可拍照 很假 高水準 庭址
#
# 【低於門檻值】	數量 375
# 威嚴 音樂會 渭水 臥室 拜拜 古亭 臺澎金馬 小品 碧湖 黃記 失望 物超所值 夏初 健行 交通狀況 絕佳 佛教 忠烈祠 演唱會 故宮 清靜 京劇 嘴饞 美景 交通阻塞 渡輪 動物園 梅龍鎮 繁華都市 善男信女 漁人 棒球 鬧市 希望 舊時代 古蹟 開放日 中山堂 佛像 平劇 銅版 安然 拱橋 毛骨悚然 吃不消 搖滾音樂 湖面 夜景 截然不同 碧潭 蓮花池 書店 奇觀 鞋店 蔣介石 動植物 戲水 值得一看 彩色 神殿 可選 遊樂區 食品街 溫泉水 水上公園 四合院 高品質 整齊 沐浴露 外雙溪 很漂亮 自然 運輸工具 誠心 歷史記錄 館藏 真棒 說得過去 海芋 沁涼 硫磺 點綴著 蛤殼 精品店 紅樓 雕像 雕刻 小鎮 莊嚴 刺激 菸廠 建築設計 情不自禁 自行車道 園藝 泡湯 古厝 鬧區 北門 茶具 碧山 拍攝 葡萄 花博 學府 搶眼 清境 花卉 仙公廟 交接儀式 蔣公 紀州 國民黨中央 噪聲 花市 擁擠 讚賞 主題公園 很棒 少數民族 文化公園 日系 發展史 花旗銀行 硬傷 禮賓 摩天大樓 草坪 國寶級 衛兵 驚訝 浴場 長廊 皇宮 蔣夫人 敗筆 進餐 遺憾 紅毛城 悲慘 萬華 花季 風景 休息 白石 聊天 藝文 老街 玩水 河景 電影院 科學 矛盾 生活空間 美聲 大腸 國父 中央研究院 航運 植物園 日常生活 紅玉 糟糕 職棒 劍南 友好 展示館 國家博物館 航海 乾枯 老字號 和諧 遺址 氣焰囂張 美術館 大海 碰碰車 小棧 時裝 雕塑 登山 蔣中正 舞會 火山口 偏遠 好棒 淡水河 犯罪 維護 古色 拓撲 科技 童年 乘船 偏貴 菁桐 自然光 大龍峒 爬山 小桌子 同性戀 樟樹 地下城 熱帶植物 觀景臺 小風 出土文物 泡溫泉 浪費 孫中山 教育 自然環境 校門 探險 寬敞 池水 晴光 釀酒廠 乘涼 彩霞 不好玩 夜市 轉到 最棒 格里芬 舒服 歷史文物 草地 小食 當代藝術 大使館 交響樂 廟口 炎熱 悠遊 快感 臺大 站崗 綠樹 舒適感 玫瑰園 熱水 袖珍 靜態 微縮 展場 陳列館 度假 露營 享受 宋美齡 藝廊 藥材 夏季 特別 小而美 太多 好訊息 酒廠 首善之區 聖誕樹 感受 喚起 年久失修 茶館 棒極了 湯屋 便宜 免費參觀 下起 山嶺 高階 貓纜 寧夏 徒步 晶華 誤導 試一下 感興趣 爆竹 教育館 靜肅 圓通寺 音樂廳 慢活 大熊貓 合適 敏感 設計規劃 必去 天燈 應急 零售店 熊貓館 徒步旅行 園林 錄影 紀念館 大廟 菊展 飢腸轆轆 神聖 詬病 擎天 社子島 中央公園 遊樂場 和平 寓教於樂 興奮 熊貓 紀念堂 晚宴 箇舊 雅緻 真實 評論 遙遠 秋日 順眼 綠洲 嬰幼兒 南海路 古街 宮殿式 義大利式 航海技術 文學 槍戰 二二八 舒暢 宗教 觀劇 城隍廟 旅行團 財神 金紙 親民 南方 志趣 博物院 陽明 火山作用 展演 淡江 負面 微型 建國中學 錦上添花 菸草 船舶 天鵝 陵墓 旅遊團 網路服務 拍照 平溪 詔書 值得 陰曆 低廉 銅像 好看 度假村 繁忙 或位 藝術品 便利店 研究所 天下第一 遊樂園 中國武術 瑞芳 慶祝 著門

# %% [markdown]
# # 使用SougoCS Model

# %%
W2V_ClassificationMethod2(Dic,'NE_SciTfidf-10-20160117.txt',0.25,0.6,'F')
# Out:
# 原總量 955 	| 去重複後 571
# --------------------------------------------------
# 【 遊玩 】 	數量: 33
# 品茶 聊天 遊樂區 玩水 必去 度假 乘船 浴場 電影院 登山 露營 長廊 徒步旅行 爬山 度假村 觀光果園 戲水 好玩 看電影 遊樂園 碰碰車 泡溫泉 教育館 健行 遊玩 植物園 遊樂 遊樂場 水上公園 悠遊 國家公園 探險 清境
#
# 【 新奇 】 	數量: 4
# 新穎 慢活 獨特 驚喜
#
# 【 懷舊 】 	數量: 6
# 復古 好看 湯屋 義大利式 異國情調 時裝
#
# 【 乾淨 】 	數量: 17
# 寬敞 沒得說 整潔 整齊 乾淨 池水 溫泉水 燙腳 熱水 沐浴露 也很不錯 小桌子 臥室 乾枯 蛤殼 潔淨 不講究
#
# 【 藝文 】 	數量: 27
# 音樂會 搖滾音樂 音樂 京劇 觀劇 國寶級 國家劇院 學府 美聲 美術 藝術品 展演 美術館 戲劇 藝文活動 戲曲 當代藝術 創意 交響樂 中國武術 新藝術 藝術 藝文 現代藝術 音樂廳 雕塑 文學
#
# 【 信仰 】 	數量: 21
# 善男信女 虔誠 神殿 蔣中正 古厝 地藏菩薩 指南宮 國父 祈福 蔣公 信仰 習俗 城隍 宗教 佛教 佛像 寺廟 祭祀 神明 香火鼎盛 信徒
#
# 【 運動 】 	數量: 1
# 運動
#
# 【 漂亮 】 	數量: 8
# 漂亮 勇敢 平凡 優美 色彩鮮豔 很漂亮 可愛 美麗
#
# 【 脫俗 】 	數量: 15
# 美景 綠樹 幽雅 優雅 自然環境 秋日 園林 清幽 繁華都市 自然 生活空間 空氣清新 點綴著 建築風格 河景
#
# 【 髒亂 】 	數量: 7
# 城隍爺 髒亂 低劣 灰塵 年久失修 很髒 著門
#
# 【 樂活 】 	數量: 2
# 環保 綠化
#
# 【 壯觀 】 	數量: 20
# 熱帶植物 渭水 淡水河 值得一看 大海 摩天大樓 奇觀 陡峭 雕像 湖面 微縮 山嶺 故宮 風景 城隍廟 夜景 碧湖 碧潭 拱橋 莊嚴
#
# 【 古老 】 	數量: 26
# 古老 古色古香 古色 廟宇 神祇 古亭 展示館 遺址 發展史 壁畫 陵墓 歷史文物 歷史悠久 雕刻 陳列館 老街 紅毛城 古舊 豐富 神聖 古蹟 古代 道教 民間信仰 古街 宮殿式
#
# 【 美食 】 	數量: 16
# 鵝肉 臭豆腐 魯肉 新鮮 葡萄 蚵仔煎 刈包 美味 小食 美食 潤餅 嘴饞 好吃 進餐 花生糖 爽口
#
# 【 安靜 】 	數量: 4
# 寧靜 安靜 清靜 鬧市
#
# 【 特產 】 	數量: 10
# 藝廊 手工藝品 翠玉白菜 精美 茶具 夜市 食品街 紀念品 花卉 工藝品
#
# 【 購物 】 	數量: 16
# 主題公園 北門 購物 精品店 繁華 便利店 零售店 書店 南海路 鞋店 一應俱全 地下商場 購物中心 應有盡有 老字號 梅龍鎮
#
# 【 有趣 】 	數量: 4
# 有趣 有教育意義 寓教於樂 有創意
#
# 【 文青 】 	數量: 15
# 威嚴 舒適感 熱情奔放 志趣 親民 充滿活力 現代感 雅緻 沁涼 精緻 容易親近 順眼 很假 莊重 柔和
#
# 【 快樂 】 	數量: 12
# 童年 溫暖 愉悅 感傷 興奮 令人愉快 愉快 幸福 熱鬧 很開心 歡樂 舒服
#
# 【 輕鬆 】 	數量: 8
# 放鬆 悠閒 休閒 享受 消遣 兒童樂園 愜意 輕鬆
#
# --------------------------------------------------------------------
# 相似度門檻 0.25 	| 相似成數門檻 0.6 　| 成功分類 272 　| 成功分類比率 47 %
# --------------------------------------------------------------------
#
# 【W2V無法辨識】	數量 22
# 老攤 聳大 傅鐘 圓湯 走往 搭貓纜 湯區 草間彌生 菁桐 椰林大道 仙公廟 碗粿 黃記 或位 紀州 吳寶春 觀光夜市 米苔目 小棧 歌劇魅影 庭址 織紡品
#
# 【低於門檻值】	數量 277
# 毛骨悚然 泡湯 有幫助 還願 犯罪 喧擾 道地 鬧區 地下城 敏感 粘著劑 大熊貓 設計規劃 可選 有特色 地下街 交通阻塞 拜拜 細緻 碧山 攤商 拍攝 合適 偏貴 孫中山 花博 熊貓館 自然光 大龍峒 搶眼 晶華 臺澎金馬 應急 彩色 同性戀 樟樹 舒暢 年輕 紀念館 維護 大廟 藥材 保生大帝 失望 菊展 物超所值 挺好玩 噪聲 觀景臺 小風 夏初 浪費 花市 深愛 擁擠 路跑 讚賞 感興趣 教育 很棒 詬病 擎天 社子島 中央公園 少數民族 絕佳 皇宮 忠烈祠 日系 演唱會 和平 花旗銀行 廟口 吃不消 真棒 硬傷 禮賓 旅行團 旅遊團 晴光 交通狀況 釀酒廠 草坪 儲存模組 熊貓 乘涼 彩霞 不好玩 紀念堂 衛兵 驚訝 校門 綠洲 截然不同 值回票價 渡輪 動物園 拓撲 下起 箇舊 轉到 文化公園 最棒 蔣夫人 會教 科技 真實 格里芬 評論 真理大學 天燈 漁人 遙遠 敗筆 舒壓 自動販賣機 大使館 草地 棒球 希望 感受 孔子廟 遺憾 太多 小鎮 嬰幼兒 炎熱 很幸運 中山堂 萬華 花季 可拍照 平劇 快感 網路服務 銅版 臺大 槍戰 二二八 站崗 很便宜 休息 白石 玫瑰園 交接儀式 袖珍 靜態 著名 平溪 研究所 值得關注 財神 展場 金紙 文化活動 叫賣 待加強 南方 靈驗 蓮花池 航運 科學 高階 白鷺鷥 矛盾 宋美齡 印象深刻 蔣介石 博物院 陽明 動植物 親切 淡江 不舒服 舊時代 職棒 值得 中央研究院 負面 特別 茶館 小而美 火山作用 劃在 微型 小品 建國中學 好訊息 外雙溪 錦上添花 錄影 菸草 棒極了 酒廠 船舶 首善之區 不喜歡 天鵝 聖誕樹 日常用品 四合院 攝影 高品質 日常生活 大腸 紅玉 喚起 安然 難以想象 開放日 非常興奮 糟糕 喜歡 沒有必要 童話故事 拍照 國民黨中央 飢腸轆轆 豬血 祈禱 詔書 運輸工具 誠心 劍南 夏季 友好 意麵 說得過去 陰曆 便宜 低廉 高水準 銅像 有禮 海芋 歷史記錄 國家博物館 硫磺 貓纜 寧夏 航海 奇怪 館藏 繁忙 和諧 艋舺 徒步 氣焰囂張 紅樓 悲慘 誤導 試一下 霧太大 晚宴 爆竹 刺激 天下第一 不為人知 菸廠 瑞芳 慶祝 完好如新 參拜 航海技術 很遺憾 舞會 建築設計 靜肅 圓通寺 免費參觀 好棒 情不自禁 火山口 出土文物 偏遠 自行車道 園藝

# %%
W2V_ClassificationMethod2(Dic,'NE_SciTfidf-10-20160117.txt',0.3,0.67,'F')
# Out:
# 原總量 955 	| 去重複後 571
# --------------------------------------------------
# 【 遊玩 】 	數量: 4
# 遊玩 好玩 徒步旅行 遊樂
#
# 【 新奇 】 	數量: 3
# 新穎 獨特 驚喜
#
# 【 懷舊 】 	數量: 1
# 復古
#
# 【 乾淨 】 	數量: 4
# 寬敞 整潔 潔淨 乾淨
#
# 【 藝文 】 	數量: 18
# 交響樂 展演 美術館 戲劇 音樂會 新藝術 藝術 音樂 現代藝術 戲曲 京劇 美聲 藝文活動 音樂廳 當代藝術 文學 創意 美術
#
# 【 信仰 】 	數量: 10
# 虔誠 地藏菩薩 信仰 習俗 宗教 佛教 寺廟 祭祀 神明 信徒
#
# 【 運動 】 	數量: 1
# 運動
#
# 【 漂亮 】 	數量: 8
# 漂亮 熱情奔放 色彩鮮豔 充滿活力 優美 很漂亮 可愛 美麗
#
# 【 脫俗 】 	數量: 3
# 優雅 清幽 幽雅
#
# 【 髒亂 】 	數量: 4
# 髒亂 低劣 灰塵 很髒
#
# 【 樂活 】 	數量: 2
# 環保 綠化
#
# 【 壯觀 】 	數量: 13
# 美景 陡峭 威嚴 宮殿式 奇觀 綠樹 熱帶植物 山嶺 風景 夜景 碧湖 碧潭 香火鼎盛
#
# 【 古老 】 	數量: 12
# 展示館 古老 發展史 古蹟 歷史文物 古色古香 古代 道教 歷史悠久 古亭 民間信仰 古街
#
# 【 美食 】 	數量: 12
# 鵝肉 臭豆腐 新鮮 蚵仔煎 刈包 美味 小食 美食 潤餅 好吃 花生糖 爽口
#
# 【 安靜 】 	數量: 8
# 寧靜 清靜 鬧市 安靜 繁華都市 生活空間 空氣清新 熱鬧
#
# 【 特產 】 	數量: 8
# 手工藝品 翠玉白菜 茶具 雕刻 紀念品 食品街 花卉 工藝品
#
# 【 購物 】 	數量: 2
# 購物中心 南海路
#
# 【 有趣 】 	數量: 2
# 有趣 有創意
#
# 【 文青 】 	數量: 9
# 舒適感 現代感 雅緻 沁涼 精緻 莊重 柔和 異國情調 慢活
#
# 【 快樂 】 	數量: 5
# 童年 幸福 愉快 溫暖 歡樂
#
# 【 輕鬆 】 	數量: 6
# 放鬆 悠閒 休閒 消遣 愜意 輕鬆
#
# --------------------------------------------------------------------
# 相似度門檻 0.3 	| 相似成數門檻 0.67 　| 成功分類 135 　| 成功分類比率 23 %
# --------------------------------------------------------------------
#
# 【W2V無法辨識】	數量 22
# 老攤 聳大 傅鐘 圓湯 走往 搭貓纜 湯區 草間彌生 菁桐 椰林大道 仙公廟 碗粿 黃記 或位 紀州 吳寶春 觀光夜市 米苔目 小棧 歌劇魅影 庭址 織紡品
#
# 【低於門檻值】	數量 414
# 粘著劑 渭水 臥室 拜拜 好訊息 臺澎金馬 小品 失望 物超所值 看電影 兒童樂園 完好如新 夏初 健行 交通狀況 絕佳 忠烈祠 演唱會 故宮 河景 聖誕樹 嘴饞 交通阻塞 渡輪 動物園 梅龍鎮 很開心 善男信女 漁人 棒球 希望 舊時代 開放日 中山堂 佛像 平劇 銅版 安然 拱橋 毛骨悚然 真理大學 吃不消 搖滾音樂 湖面 截然不同 廟宇 蓮花池 書店 鞋店 蔣介石 動植物 觀光果園 戲水 古舊 值得一看 值得 神殿 壁畫 沒有必要 可選 遊樂區 溫泉水 水上公園 四合院 很假 攝影 高品質 整齊 品茶 沐浴露 外雙溪 自然 運輸工具 誠心 歷史記錄 館藏 真棒 說得過去 有禮 海芋 硫磺 奇怪 點綴著 蛤殼 艋舺 精品店 紅樓 雕像 小鎮 莊嚴 登山 菸廠 豐富 參拜 精美 建築設計 祈福 情不自禁 自行車道 園藝 泡湯 古厝 鬧區 地下城 地下街 碧山 魯肉 拍攝 葡萄 花博 感傷 學府 搶眼 清境 還願 交接儀式 蔣公 國民黨中央 噪聲 建築風格 花市 擁擠 讚賞 主題公園 很棒 少數民族 文化公園 日系 花旗銀行 硬傷 禮賓 摩天大樓 草坪 國寶級 衛兵 驚訝 浴場 長廊 皇宮 蔣夫人 會教 沒得說 敗筆 自動販賣機 進餐 靈驗 遺憾 紅毛城 悲慘 萬華 花季 可拍照 休息 白石 聊天 藝文 老街 玩水 電影院 科學 矛盾 印象深刻 不舒服 大腸 國父 中央研究院 應急 航運 植物園 令人愉快 日常生活 紅玉 難以想象 非常興奮 糟糕 職棒 童話故事 豬血 劍南 友好 繁華 國家博物館 航海 乾枯 老字號 和諧 城隍 文化活動 氣焰囂張 大海 有幫助 碰碰車 時裝 蔣中正 舞會 火山口 偏遠 好棒 微型 淡水河 犯罪 道地 維護 大熊貓 古色 拓撲 科技 攤商 乘船 偏貴 自然光 大龍峒 爬山 有教育意義 小桌子 同性戀 樟樹 年輕 北門 觀景臺 小風 出土文物 泡溫泉 浪費 孫中山 路跑 教育 自然環境 校門 探險 池水 晴光 釀酒廠 乘涼 彩霞 不好玩 遺址 值回票價 夜市 轉到 最棒 格里芬 舒服 舒壓 草地 大使館 廟口 愉悅 炎熱 很幸運 悠遊 快感 臺大 站崗 很便宜 玫瑰園 熱水 袖珍 靜態 微縮 著名 展場 陳列館 度假 指南宮 露營 享受 白鷺鷥 旅行團 宋美齡 不喜歡 藝廊 藥材 夏季 特別 小而美 太多 細緻 酒廠 首善之區 地下商場 一應俱全 日常用品 感受 喚起 年久失修 茶館 棒極了 祈禱 湯屋 便宜 免費參觀 高水準 下起 高階 貓纜 寧夏 徒步 晶華 誤導 試一下 感興趣 爆竹 教育館 喜歡 靜肅 圓通寺 城隍爺 雕塑 燙腳 合適 喧擾 敏感 設計規劃 有特色 必去 不為人知 天燈 神祇 零售店 熊貓館 園林 平凡 錄影 紀念館 大廟 保生大帝 菊展 飢腸轆轆 挺好玩 神聖 詬病 擎天 社子島 中央公園 遊樂場 和平 彩色 寓教於樂 興奮 熊貓 親切 紀念堂 國家公園 晚宴 箇舊 容易親近 真實 評論 勇敢 遙遠 秋日 順眼 儲存模組 刺激 綠洲 孔子廟 應有盡有 嬰幼兒 深愛 義大利式 航海技術 槍戰 二二八 舒暢 觀劇 城隍廟 研究所 值得關注 財神 金紙 叫賣 不講究 待加強 親民 南方 志趣 博物院 陽明 火山作用 淡江 負面 劃在 也很不錯 建國中學 錦上添花 菸草 船舶 天鵝 陵墓 旅遊團 網路服務 拍照 平溪 詔書 意麵 陰曆 國家劇院 低廉 銅像 好看 度假村 繁忙 藝術品 便利店 霧太大 購物 天下第一 遊樂園 中國武術 瑞芳 慶祝 很遺憾 著門

# %% [markdown]
# # 使用SougoCA Model

# %%
W2V_ClassificationMethod2(Dic,'NE_SciTfidf-10-20160117.txt',0.25,0.6,'F')
# Out:
# 原總量 955 	| 去重複後 571
# --------------------------------------------------
# 【 遊玩 】 	數量: 22
# 遊樂區 玩水 美景 購物 電影院 動物園 露營 度假村 戲水 好玩 看電影 遊樂園 兒童樂園 碰碰車 泡溫泉 浴場 遊玩 遊樂 植物園 遊樂場 免費參觀 探險
#
# 【 新奇 】 	數量: 4
# 新穎 獨特 寓教於樂 驚喜
#
# 【 懷舊 】 	數量: 16
# 舊時代 菊展 新藝術 色彩鮮豔 舞會 現代感 感傷 雅緻 復古 精緻 容易親近 夏初 觀劇 莊重 異國情調 點綴著
#
# 【 乾淨 】 	數量: 9
# 整潔 整齊 乾淨 舒壓 熱水 沐浴露 空氣清新 乾枯 潔淨
#
# 【 藝文 】 	數量: 20
# 交響樂 文學 展演 國家劇院 戲劇 音樂會 搖滾音樂 藝術 音樂 現代藝術 戲曲 京劇 美聲 音樂廳 小品 雕刻 當代藝術 藝文 創意 美術
#
# 【 信仰 】 	數量: 23
# 虔誠 古厝 信仰 宗教 寺廟 紀念堂 香火鼎盛 廟宇 翠玉白菜 神明 善男信女 國父 城隍 保生大帝 神殿 壁畫 祭祀 孫中山 佛教 忠烈祠 佛像 陵墓 信徒
#
# 【 運動 】 	數量: 1
# 運動
#
# 【 漂亮 】 	數量: 9
# 漂亮 熱情奔放 優美 很漂亮 童話故事 好看 可愛 美麗 勇敢
#
# 【 脫俗 】 	數量: 11
# 綠樹 舒適感 優雅 秋日 沁涼 悠遊 清幽 幽雅 生活空間 義大利式 古色
#
# 【 髒亂 】 	數量: 9
# 古舊 完好如新 髒亂 低劣 著門 灰塵 不講究 很髒 年久失修
#
# 【 樂活 】 	數量: 7
# 環保 噪聲 自然環境 自然光 熱帶植物 綠化 教育館
#
# 【 壯觀 】 	數量: 20
# 紀念館 陡峭 長廊 地下城 大海 摩天大樓 奇觀 雕像 湖面 微縮 山嶺 古色古香 莊嚴 古街 夜景 老街 雕塑 故宮 碧潭 綠洲
#
# 【 古老 】 	數量: 17
# 古代 主題公園 陳列館 遺址 發展史 古蹟 歷史文物 建築風格 習俗 道教 歷史悠久 少數民族 古老 航海 宮殿式 民間信仰 老字號
#
# 【 美食 】 	數量: 18
# 鵝肉 臭豆腐 魯肉 新鮮 葡萄 嘴饞 蚵仔煎 道地 飢腸轆轆 燙腳 美味 小食 小風 美食 豬血 好吃 進餐 爽口
#
# 【 安靜 】 	數量: 5
# 繁華都市 寧靜 安靜 清靜 寬敞
#
# 【 特產 】 	數量: 10
# 手工藝品 藝術品 精美 茶具 必去 紀念品 日常用品 花卉 應有盡有 工藝品
#
# 【 購物 】 	數量: 19
# 北門 書店 精品店 蓮花池 繁華 便利店 零售店 鞋店 中央公園 夜市 展示館 地下商場 購物中心 四合院 城隍廟 鬧市 碧湖 花市 梅龍鎮
#
# 【 有趣 】 	數量: 3
# 有趣 刺激 有創意
#
# 【 文青 】 	數量: 6
# 威嚴 沒得說 親民 充滿活力 風景 柔和
#
# 【 快樂 】 	數量: 26
# 非常興奮 喜歡 興奮 愉快 歡樂 友好 童年 享受 很開心 舒服 和諧 親切 值得 失望 遙遠 悲慘 希望 神聖 遺憾 愉悅 溫暖 慶祝 令人愉快 感受 熱鬧 幸福
#
# 【 輕鬆 】 	數量: 7
# 放鬆 悠閒 品茶 休閒 消遣 愜意 輕鬆
#
# --------------------------------------------------------------------
# 相似度門檻 0.25 	| 相似成數門檻 0.6 　| 成功分類 262 　| 成功分類比率 45 %
# --------------------------------------------------------------------
#
# 【W2V無法辨識】	數量 48
# 真理大學 花博 河景 聳大 傅鐘 霧太大 粘著劑 湯屋 花生糖 大龍峒 走往 圓湯 碧山 搭貓纜 湯區 攤商 城隍爺 草間彌生 老攤 古亭 白鷺鷥 菁桐 椰林大道 仙公廟 貓纜 碗粿 蛤殼 觀光果園 或位 紀州 吳寶春 艋舺 地藏菩薩 觀光夜市 米苔目 小棧 孔子廟 歌劇魅影 指南宮 庭址 神祇 社子島 刈包 紅毛城 織紡品 平劇 黃記 潤餅
#
# 【低於門檻值】	數量 261
# 毛骨悚然 泡湯 有幫助 犯罪 喧擾 鬧區 敏感 晴光 維護 大熊貓 設計規劃 渭水 可選 有特色 臥室 交通阻塞 拜拜 細緻 科技 天燈 乘船 拍攝 合適 偏貴 熊貓館 徒步旅行 學府 園林 搶眼 臺澎金馬 應急 小桌子 清境 同性戀 樟樹 舒暢 寧夏 路跑 大廟 國民黨中央 下起 物超所值 挺好玩 聊天 觀景臺 出土文物 浪費 深愛 擁擠 健行 讚賞 感興趣 很棒 教育 詬病 擎天 交通狀況 校門 絕佳 皇宮 文化公園 日系 演唱會 和平 彩色 廟口 吃不消 真棒 硬傷 池水 禮賓 旅行團 旅遊團 也很不錯 釀酒廠 草坪 儲存模組 熊貓 地下街 彩霞 不好玩 國寶級 衛兵 驚訝 國家公園 截然不同 值回票價 渡輪 拓撲 箇舊 轉到 最棒 蔣夫人 會教 不為人知 真實 格里芬 評論 待加強 漁人 敗筆 自動販賣機 草地 棒球 順眼 大使館 靈驗 淡水河 錄影 太多 晶華 宋美齡 嬰幼兒 炎熱 南海路 很幸運 中山堂 萬華 花季 可拍照 花旗銀行 快感 網路服務 銅版 臺大 拱橋 二二八 站崗 很便宜 休息 白石 玫瑰園 交接儀式 袖珍 靜態 著名 平溪 研究所 值得關注 財神 展場 金紙 叫賣 度假 爬山 南方 志趣 航運 科學 高階 矛盾 有教育意義 印象深刻 蔣介石 博物院 陽明 動植物 淡江 不舒服 藝廊 值得一看 夏季 中央研究院 負面 特別 藝文活動 茶館 小而美 火山作用 劃在 微型 還願 建國中學 好訊息 外雙溪 錦上添花 食品街 菸草 酒廠 船舶 首善之區 天鵝 溫泉水 聖誕樹 一應俱全 水上公園 安然 不喜歡 很假 攝影 高品質 日常生活 大腸 紅玉 喚起 難以想象 槍戰 開放日 祈禱 糟糕 職棒 沒有必要 拍照 棒極了 藥材 自然 詔書 運輸工具 誠心 劍南 館藏 年輕 意麵 說得過去 陰曆 便宜 祈福 高水準 銅像 有禮 海芋 歷史記錄 國家博物館 硫磺 蔣公 奇怪 繁忙 平凡 文化活動 徒步 氣焰囂張 美術館 紅樓 乘涼 小鎮 誤導 試一下 晚宴 爆竹 時裝 登山 天下第一 菸廠 豐富 中國武術 瑞芳 參拜 航海技術 蔣中正 很遺憾 建築設計 靜肅 圓通寺 低廉 好棒 情不自禁 火山口 慢活 偏遠 自行車道 園藝

# %%
W2V_ClassificationMethod2(Dic,'NE_SciTfidf-10-20160117.txt',0.3,0.67,'F')
# Out:
# 原總量 955 	| 去重複後 571
# --------------------------------------------------
# 【 遊玩 】 	數量: 3
# 遊玩 好玩 遊樂
#
# 【 新奇 】 	數量: 4
# 新穎 獨特 寓教於樂 驚喜
#
# 【 懷舊 】 	數量: 4
# 舊時代 異國情調 復古 秋日
#
# 【 乾淨 】 	數量: 3
# 整潔 潔淨 乾淨
#
# 【 藝文 】 	數量: 13
# 交響樂 文學 展演 戲劇 藝術 音樂 現代藝術 戲曲 京劇 小品 藝文 創意 美術
#
# 【 信仰 】 	數量: 7
# 虔誠 信仰 宗教 佛教 祭祀 神明 信徒
#
# 【 運動 】 	數量: 1
# 運動
#
# 【 漂亮 】 	數量: 5
# 熱情奔放 漂亮 美麗 優美 可愛
#
# 【 脫俗 】 	數量: 6
# 優雅 色彩鮮豔 清幽 風景 幽雅 點綴著
#
# 【 髒亂 】 	數量: 4
# 髒亂 低劣 灰塵 很髒
#
# 【 樂活 】 	數量: 2
# 環保 綠化
#
# 【 壯觀 】 	數量: 8
# 美景 綠樹 大海 古色古香 奇觀 湖面 古街 夜景
#
# 【 古老 】 	數量: 12
# 古老 遺址 古蹟 古代 建築風格 自然環境 歷史文物 道教 歷史悠久 民間信仰 發展史 習俗
#
# 【 美食 】 	數量: 17
# 鵝肉 臭豆腐 魯肉 新鮮 葡萄 蚵仔煎 嘴饞 看電影 美味 小食 飢腸轆轆 美食 豬血 好吃 進餐 應有盡有 爽口
#
# 【 安靜 】 	數量: 5
# 清靜 寧靜 安靜 空氣清新 寬敞
#
# 【 特產 】 	數量: 4
# 紀念品 手工藝品 日常用品 茶具
#
# 【 購物 】 	數量: 4
# 便利店 購物中心 城隍廟 夜市
#
# 【 有趣 】 	數量: 1
# 有趣
#
# 【 文青 】 	數量: 5
# 雅緻 柔和 精緻 充滿活力 現代感
#
# 【 快樂 】 	數量: 8
# 溫暖 愉悅 享受 令人愉快 愉快 幸福 熱鬧 歡樂
#
# 【 輕鬆 】 	數量: 6
# 放鬆 悠閒 休閒 消遣 愜意 輕鬆
#
# --------------------------------------------------------------------
# 相似度門檻 0.3 	| 相似成數門檻 0.67 　| 成功分類 122 　| 成功分類比率 21 %
# --------------------------------------------------------------------
#
# 【W2V無法辨識】	數量 48
# 真理大學 花博 河景 聳大 傅鐘 霧太大 粘著劑 湯屋 花生糖 大龍峒 走往 圓湯 碧山 搭貓纜 湯區 攤商 城隍爺 草間彌生 老攤 古亭 白鷺鷥 菁桐 椰林大道 仙公廟 貓纜 碗粿 蛤殼 觀光果園 或位 紀州 吳寶春 艋舺 地藏菩薩 觀光夜市 米苔目 小棧 孔子廟 歌劇魅影 指南宮 庭址 神祇 社子島 刈包 紅毛城 織紡品 平劇 黃記 潤餅
#
# 【低於門檻值】	數量 401
# 威嚴 音樂會 陡峭 渭水 臥室 拜拜 好訊息 臺澎金馬 碧湖 失望 物超所值 志趣 兒童樂園 完好如新 夏初 矛盾 健行 交通狀況 絕佳 忠烈祠 演唱會 故宮 儲存模組 交通阻塞 渡輪 動物園 梅龍鎮 很開心 繁華都市 善男信女 漁人 棒球 鬧市 希望 開放日 中山堂 佛像 銅版 安然 拱橋 毛骨悚然 吃不消 搖滾音樂 截然不同 碧潭 香火鼎盛 廟宇 蓮花池 書店 鞋店 蔣介石 動植物 戲水 古舊 值得一看 值得 神殿 壁畫 沒有必要 可選 遊樂區 食品街 溫泉水 水上公園 四合院 很假 攝影 高品質 整齊 品茶 沐浴露 外雙溪 很漂亮 自然 運輸工具 誠心 歷史記錄 館藏 真棒 說得過去 有禮 海芋 沁涼 硫磺 奇怪 精品店 紅樓 雕像 雕刻 小鎮 莊嚴 登山 菸廠 豐富 參拜 精美 建築設計 祈福 情不自禁 自行車道 園藝 泡湯 古厝 鬧區 北門 地下街 拍攝 感傷 學府 搶眼 清境 花卉 還願 交接儀式 蔣公 國民黨中央 噪聲 莊重 花市 擁擠 讚賞 主題公園 很棒 少數民族 文化公園 日系 花旗銀行 硬傷 禮賓 摩天大樓 草坪 國寶級 衛兵 驚訝 浴場 長廊 叫賣 皇宮 蔣夫人 會教 沒得說 敗筆 自動販賣機 遺憾 悲慘 萬華 花季 可拍照 休息 白石 聊天 老街 玩水 電影院 科學 航運 晚宴 印象深刻 不舒服 生活空間 美聲 大腸 國父 中央研究院 地下商場 植物園 日常生活 紅玉 難以想象 非常興奮 糟糕 職棒 童話故事 有創意 劍南 友好 繁華 展示館 國家博物館 航海 乾枯 老字號 和諧 城隍 文化活動 氣焰囂張 美術館 有幫助 碰碰車 翠玉白菜 時裝 慢活 蔣中正 舞會 火山口 偏遠 好棒 微型 淡水河 犯罪 道地 維護 大熊貓 古色 拓撲 科技 童年 乘船 偏貴 自然光 爬山 有教育意義 小桌子 同性戀 樟樹 年輕 地下城 熱帶植物 觀景臺 小風 出土文物 泡溫泉 浪費 孫中山 路跑 教育 校門 探險 池水 晴光 釀酒廠 乘涼 彩霞 不好玩 值回票價 轉到 最棒 格里芬 舒服 舒壓 草地 當代藝術 大使館 廟口 炎熱 很幸運 悠遊 快感 臺大 站崗 很便宜 舒適感 玫瑰園 熱水 袖珍 靜態 微縮 著名 展場 陳列館 度假 露營 宋美齡 不喜歡 藝廊 藥材 夏季 特別 藝文活動 小而美 太多 細緻 酒廠 首善之區 聖誕樹 一應俱全 感受 喚起 年久失修 茶館 棒極了 祈禱 便宜 免費參觀 高水準 下起 山嶺 高階 寧夏 徒步 晶華 誤導 試一下 感興趣 爆竹 教育館 喜歡 靜肅 圓通寺 音樂廳 雕塑 燙腳 合適 喧擾 敏感 設計規劃 有特色 必去 不為人知 天燈 應急 零售店 熊貓館 徒步旅行 園林 平凡 錄影 紀念館 大廟 保生大帝 菊展 挺好玩 神聖 詬病 擎天 中央公園 遊樂場 和平 彩色 興奮 熊貓 親切 紀念堂 國家公園 購物 箇舊 容易親近 真實 評論 勇敢 遙遠 順眼 刺激 綠洲 嬰幼兒 南海路 深愛 宮殿式 義大利式 航海技術 槍戰 二二八 舒暢 觀劇 旅行團 值得關注 財神 金紙 工藝品 不講究 待加強 親民 南方 靈驗 博物院 陽明 火山作用 淡江 負面 劃在 也很不錯 建國中學 錦上添花 菸草 船舶 天鵝 陵墓 旅遊團 網路服務 拍照 平溪 寺廟 詔書 意麵 陰曆 國家劇院 低廉 銅像 好看 度假村 繁忙 藝術品 研究所 天下第一 遊樂園 中國武術 瑞芳 慶祝 很遺憾 新藝術 著門
